# %% [markdown]
# Toronto Data--Data Manipulation

# %%
#scraping Toronto data from Wikipedia webpage
import urllib.request

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
req = urllib.request.urlopen(url)
article = req.read().decode()

with open('Toronto_Neighborhoods_Wikipedia.html', 'w') as fo:
    fo.write(article)

from bs4 import BeautifulSoup

# Load article, turn into soup and get the <table>s.
article = open('Toronto_Neighborhoods_Wikipedia.html').read()
soup = BeautifulSoup(article, 'html.parser')
tables = soup.find_all('table', class_='sortable')

# Search through the tables for the one with the headings we want.
for table in tables:
    ths = table.find_all('th')
    headings = [th.text.strip() for th in ths]
    if headings[:3] == ['Postcode', 'Borough', 'Neighbourhood']:
        break

# Extract the columns we want and write to a semicolon-delimited text file.
with open('Toronto_Neighborhoods_Wikipedia.csv', 'w') as fo:
    for tr in table.find_all('tr'):
        tds = tr.find_all('td')
        if not tds:
            continue
        Postcode, Borough, Neighbourhood= [td.text.strip() for td in tds[:3]]
        # Wikipedia does something funny with country names containing
        # accented characters: extract the correct string form.
       
        print('; '.join([Postcode, Borough, Neighbourhood]), file=fo)
        
import pandas as pd

df = pd.read_csv('Toronto_Neighborhoods_Wikipedia.csv', sep=';', header=None, names=['PostalCode', 'Borough', 'Neighborhood'])

df
# Out:
#     PostalCode            Borough  \
# 0          M1A       Not assigned
# 1          M2A       Not assigned
# 2          M3A         North York
# 3          M4A         North York
# 4          M5A   Downtown Toronto
# 5          M5A   Downtown Toronto
# 6          M6A         North York
# 7          M6A         North York
# 8          M7A       Queen's Park
# 9          M8A       Not assigned
# 10         M9A          Etobicoke
# 11         M1B        Scarborough
# 12         M1B        Scarborough
# 13         M2B       Not assigned
# 14         M3B         North York
# 15         M4B          East York
# 16         M4B          East York
# 17         M5B   Downtown Toronto
# 18         M5B   Downtown Toronto
# 19         M6B         North York
# 20         M7B       Not assigned
# 21         M8B       Not assigned
# 22         M9B          Etobicoke
# 23         M9B          Etobicoke
# 24         M9B          Etobicoke
# 25         M9B          Etobicoke
# 26         M9B          Etobicoke
# 27         M1C        Scarborough
# 28         M1C        Scarborough
# 29         M1C        Scarborough
# ..         ...                ...
# 258        M9X       Not assigned
# 259        M1Y       Not assigned
# 260        M2Y       Not assigned
# 261        M3Y       Not assigned
# 262        M4Y   Downtown Toronto
# 263        M5Y       Not assigned
# 264        M6Y       Not assigned
# 265        M7Y       East Toronto
# 266        M8Y          Etobicoke
# 267        M8Y          Etobicoke
# 268        M8Y          Etobicoke
# 269        M8Y          Etobicoke
# 270        M8Y          Etobicoke
# 271        M8Y          Etobicoke
# 272        M8Y          Etobicoke
# 273        M8Y          Etobicoke
# 274        M9Y       Not assigned
# 275        M1Z       Not assigned
# 276        M2Z       Not assigned
# 277        M3Z       Not assigned
# 278        M4Z       Not assigned
# 279        M5Z       Not assigned
# 280        M6Z       Not assigned
# 281        M7Z       Not assigned
# 282        M8Z          Etobicoke
# 283        M8Z          Etobicoke
# 284        M8Z          Etobicoke
# 285        M8Z          Etobicoke
# 286        M8Z          Etobicoke
# 287        M9Z       Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265   Business Reply Mail Processing Centre 969 Eas...
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %%
# delete rows with Borough is "Not assigned"
df1=df[~df['Borough'].str.contains("Not")]
df1
# Out:
#     PostalCode            Borough  \
# 2          M3A         North York
# 3          M4A         North York
# 4          M5A   Downtown Toronto
# 5          M5A   Downtown Toronto
# 6          M6A         North York
# 7          M6A         North York
# 8          M7A       Queen's Park
# 10         M9A          Etobicoke
# 11         M1B        Scarborough
# 12         M1B        Scarborough
# 14         M3B         North York
# 15         M4B          East York
# 16         M4B          East York
# 17         M5B   Downtown Toronto
# 18         M5B   Downtown Toronto
# 19         M6B         North York
# 22         M9B          Etobicoke
# 23         M9B          Etobicoke
# 24         M9B          Etobicoke
# 25         M9B          Etobicoke
# 26         M9B          Etobicoke
# 27         M1C        Scarborough
# 28         M1C        Scarborough
# 29         M1C        Scarborough
# 31         M3C         North York
# 32         M3C         North York
# 33         M4C          East York
# 34         M5C   Downtown Toronto
# 35         M6C               York
# 38         M9C          Etobicoke
# ..         ...                ...
# 235        M9V          Etobicoke
# 236        M1W        Scarborough
# 239        M4W   Downtown Toronto
# 240        M5W   Downtown Toronto
# 243        M8W          Etobicoke
# 244        M8W          Etobicoke
# 245        M9W          Etobicoke
# 246        M1X        Scarborough
# 249        M4X   Downtown Toronto
# 250        M4X   Downtown Toronto
# 251        M5X   Downtown Toronto
# 252        M5X   Downtown Toronto
# 255        M8X          Etobicoke
# 256        M8X          Etobicoke
# 257        M8X          Etobicoke
# 262        M4Y   Downtown Toronto
# 265        M7Y       East Toronto
# 266        M8Y          Etobicoke
# 267        M8Y          Etobicoke
# 268        M8Y          Etobicoke
# 269        M8Y          Etobicoke
# 270        M8Y          Etobicoke
# 271        M8Y          Etobicoke
# 272        M8Y          Etobicoke
# 273        M8Y          Etobicoke
# 282        M8Z          Etobicoke
# 283        M8Z          Etobicoke
# 284        M8Z          Etobicoke
# 285        M8Z          Etobicoke
# 286        M8Z          Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265   Business Reply Mail Processing Centre 969 Eas...
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
df1.index
df2=df1.reset_index(drop=True) #make index from 0 to 210. Because next I am going to use .loc function
df2
# Out:
#     PostalCode            Borough  \
# 0          M3A         North York
# 1          M4A         North York
# 2          M5A   Downtown Toronto
# 3          M5A   Downtown Toronto
# 4          M6A         North York
# 5          M6A         North York
# 6          M7A       Queen's Park
# 7          M9A          Etobicoke
# 8          M1B        Scarborough
# 9          M1B        Scarborough
# 10         M3B         North York
# 11         M4B          East York
# 12         M4B          East York
# 13         M5B   Downtown Toronto
# 14         M5B   Downtown Toronto
# 15         M6B         North York
# 16         M9B          Etobicoke
# 17         M9B          Etobicoke
# 18         M9B          Etobicoke
# 19         M9B          Etobicoke
# 20         M9B          Etobicoke
# 21         M1C        Scarborough
# 22         M1C        Scarborough
# 23         M1C        Scarborough
# 24         M3C         North York
# 25         M3C         North York
# 26         M4C          East York
# 27         M5C   Downtown Toronto
# 28         M6C               York
# 29         M9C          Etobicoke
# ..         ...                ...
# 181        M9V          Etobicoke
# 182        M1W        Scarborough
# 183        M4W   Downtown Toronto
# 184        M5W   Downtown Toronto
# 185        M8W          Etobicoke
# 186        M8W          Etobicoke
# 187        M9W          Etobicoke
# 188        M1X        Scarborough
# 189        M4X   Downtown Toronto
# 190        M4X   Downtown Toronto
# 191        M5X   Downtown Toronto
# 192        M5X   Downtown Toronto
# 193        M8X          Etobicoke
# 194        M8X          Etobicoke
# 195        M8X          Etobicoke
# 196        M4Y   Downtown Toronto
# 197        M7Y       East Toronto
# 198        M8Y          Etobicoke
# 199        M8Y          Etobicoke
# 200        M8Y          Etobicoke
# 201        M8Y          Etobicoke
# 202        M8Y          Etobicoke
# 203        M8Y          Etobicoke
# 204        M8Y          Etobicoke
# 205        M8Y          Etobicoke
# 206        M8Z          Etobicoke
# 207        M8Z          Etobicoke
# 208        M8Z          Etobicoke
# 209        M8Z          Etobicoke
# 210        M8Z          Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197   Business Reply Mail Processing Centre 969 Eas...
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
#If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
import numpy as np
for i in range(0,len(df2)-1):
    if "Not" in df2.loc[i,'Neighborhood']:df2.loc[i,'Neighborhood']=df2.loc[i,'Borough']

# %%
# add column 'flag' which is used to flag records which will be used later.
# if multiple PostalCode, then flat the last item 1;
# in last step, only keep one row for each postalcode
df2['flag'] = (df2.PostalCode != df2.PostalCode.shift(-1)).astype(int)

df2
# Out:
#     PostalCode            Borough  \
# 0          M3A         North York
# 1          M4A         North York
# 2          M5A   Downtown Toronto
# 3          M5A   Downtown Toronto
# 4          M6A         North York
# 5          M6A         North York
# 6          M7A       Queen's Park
# 7          M9A          Etobicoke
# 8          M1B        Scarborough
# 9          M1B        Scarborough
# 10         M3B         North York
# 11         M4B          East York
# 12         M4B          East York
# 13         M5B   Downtown Toronto
# 14         M5B   Downtown Toronto
# 15         M6B         North York
# 16         M9B          Etobicoke
# 17         M9B          Etobicoke
# 18         M9B          Etobicoke
# 19         M9B          Etobicoke
# 20         M9B          Etobicoke
# 21         M1C        Scarborough
# 22         M1C        Scarborough
# 23         M1C        Scarborough
# 24         M3C         North York
# 25         M3C         North York
# 26         M4C          East York
# 27         M5C   Downtown Toronto
# 28         M6C               York
# 29         M9C          Etobicoke
# ..         ...                ...
# 181        M9V          Etobicoke
# 182        M1W        Scarborough
# 183        M4W   Downtown Toronto
# 184        M5W   Downtown Toronto
# 185        M8W          Etobicoke
# 186        M8W          Etobicoke
# 187        M9W          Etobicoke
# 188        M1X        Scarborough
# 189        M4X   Downtown Toronto
# 190        M4X   Downtown Toronto
# 191        M5X   Downtown Toronto
# 192        M5X   Downtown Toronto
# 193        M8X          Etobicoke
# 194        M8X          Etobicoke
# 195        M8X          Etobicoke
# 196        M4Y   Downtown Toronto
# 197        M7Y       East Toronto
# 198        M8Y          Etobicoke
# 199        M8Y          Etobicoke
# 200        M8Y          Etobicoke
# 201        M8Y          Etobicoke
# 202        M8Y          Etobicoke
# 203        M8Y          Etobicoke
# 204        M8Y          Etobicoke
# 205        M8Y          Etobicoke
# 206        M8Z          Etobicoke
# 207        M8Z          Etobicoke
# 208        M8Z          Etobicoke
# 209        M8Z          Etobicoke
# 210        M8Z          Etobicoke
#
#                                           Neighborhood  flag
# 0                                            Parkwoods     1
# 1                                     Victoria Village     1
# 2                                         Harbourfront     0
# 3                                          Regent Park     1
# 4                                     Lawrence Heights     0
# 5                                       Lawrence Manor     1
# 6                                         Queen's Park     1
# 7                                     Islington Avenue     1
# 8                                                Rouge     0
# 9                                              Malvern     1
# 10                                     Don Mills North     1
# 11                                    Woodbine Gardens     0
# 12                                       Parkview Hill     1
# 13                                             Ryerson     0
# 14                                     Garden District     1
# 15                                           Glencairn     1
# 16                                          Cloverdale     0
# 17                                           Islington     0
# 18                                        Martin Grove     0
# 19                                    Princess Gardens     0
# 20                                     West Deane Park     1
# 21                                      Highland Creek     0
# 22                                          Rouge Hill     0
# 23                                          Port Union     1
# 24                                     Flemingdon Park     0
# 25                                     Don Mills South     1
# 26                                    Woodbine Heights     1
# 27                                      St. James Town     1
# 28                                  Humewood-Cedarvale     1
# 29                                   Bloordale Gardens     0
# ..                                                 ...   ...
# 181                                        Thistletown     1
# 182                                    L'Amoreaux West     1
# 183                                           Rosedale     1
# 184                    Stn A PO Boxes 25 The Esplanade     1
# 185                                          Alderwood     0
# 186                                        Long Branch     1
# 187                                          Northwest     1
# 188                                        Upper Rouge     1
# 189                                        Cabbagetown     0
# 190                                     St. James Town     1
# 191                               First Canadian Place     0
# 192                                   Underground city     1
# 193                                       The Kingsway     0
# 194                                    Montgomery Road     0
# 195                                     Old Mill North     1
# 196                               Church and Wellesley     1
# 197   Business Reply Mail Processing Centre 969 Eas...     1
# 198                                         Humber Bay     0
# 199                                   King's Mill Park     0
# 200                           Kingsway Park South East     0
# 201                                          Mimico NE     0
# 202                                     Old Mill South     0
# 203                                 The Queensway East     0
# 204                              Royal York South East     0
# 205                                           Sunnylea     1
# 206                           Kingsway Park South West     0
# 207                                          Mimico NW     0
# 208                                 The Queensway West     0
# 209                              Royal York South West     0
# 210                                     South of Bloor     1
#
# [211 rows x 4 columns]

# %%
#More than one neighborhood can exist in one postal code area. 
#For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: 
#Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma

df2.loc[0,'Combined_Neighborhood']=df2.loc[0,'Neighborhood']
for i in range(1,len(df2)):
 if df2.loc[i,'PostalCode'] == df2.loc[i-1,'PostalCode']:
      df2.loc[i,'Combined_Neighborhood']=df2.loc[i,'Neighborhood']+','+df2.loc[i-1,'Combined_Neighborhood']
 else: df2.loc[i,'Combined_Neighborhood']=df2.loc[i,'Neighborhood']

df2
# Out:
#     PostalCode            Borough  \
# 0          M3A         North York
# 1          M4A         North York
# 2          M5A   Downtown Toronto
# 3          M5A   Downtown Toronto
# 4          M6A         North York
# 5          M6A         North York
# 6          M7A       Queen's Park
# 7          M9A          Etobicoke
# 8          M1B        Scarborough
# 9          M1B        Scarborough
# 10         M3B         North York
# 11         M4B          East York
# 12         M4B          East York
# 13         M5B   Downtown Toronto
# 14         M5B   Downtown Toronto
# 15         M6B         North York
# 16         M9B          Etobicoke
# 17         M9B          Etobicoke
# 18         M9B          Etobicoke
# 19         M9B          Etobicoke
# 20         M9B          Etobicoke
# 21         M1C        Scarborough
# 22         M1C        Scarborough
# 23         M1C        Scarborough
# 24         M3C         North York
# 25         M3C         North York
# 26         M4C          East York
# 27         M5C   Downtown Toronto
# 28         M6C               York
# 29         M9C          Etobicoke
# ..         ...                ...
# 181        M9V          Etobicoke
# 182        M1W        Scarborough
# 183        M4W   Downtown Toronto
# 184        M5W   Downtown Toronto
# 185        M8W          Etobicoke
# 186        M8W          Etobicoke
# 187        M9W          Etobicoke
# 188        M1X        Scarborough
# 189        M4X   Downtown Toronto
# 190        M4X   Downtown Toronto
# 191        M5X   Downtown Toronto
# 192        M5X   Downtown Toronto
# 193        M8X          Etobicoke
# 194        M8X          Etobicoke
# 195        M8X          Etobicoke
# 196        M4Y   Downtown Toronto
# 197        M7Y       East Toronto
# 198        M8Y          Etobicoke
# 199        M8Y          Etobicoke
# 200        M8Y          Etobicoke
# 201        M8Y          Etobicoke
# 202        M8Y          Etobicoke
# 203        M8Y          Etobicoke
# 204        M8Y          Etobicoke
# 205        M8Y          Etobicoke
# 206        M8Z          Etobicoke
# 207        M8Z          Etobicoke
# 208        M8Z          Etobicoke
# 209        M8Z          Etobicoke
# 210        M8Z          Etobicoke
#
#                                           Neighborhood  flag  \
# 0                                            Parkwoods     1
# 1                                     Victoria Village     1
# 2                                         Harbourfront     0
# 3                                          Regent Park     1
# 4                                     Lawrence Heights     0
# 5                                       Lawrence Manor     1
# 6                                         Queen's Park     1
# 7                                     Islington Avenue     1
# 8                                                Rouge     0
# 9                                              Malvern     1
# 10                                     Don Mills North     1
# 11                                    Woodbine Gardens     0
# 12                                       Parkview Hill     1
# 13                                             Ryerson     0
# 14                                     Garden District     1
# 15                                           Glencairn     1
# 16                                          Cloverdale     0
# 17                                           Islington     0
# 18                                        Martin Grove     0
# 19                                    Princess Gardens     0
# 20                                     West Deane Park     1
# 21                                      Highland Creek     0
# 22                                          Rouge Hill     0
# 23                                          Port Union     1
# 24                                     Flemingdon Park     0
# 25                                     Don Mills South     1
# 26                                    Woodbine Heights     1
# 27                                      St. James Town     1
# 28                                  Humewood-Cedarvale     1
# 29                                   Bloordale Gardens     0
# ..                                                 ...   ...
# 181                                        Thistletown     1
# 182                                    L'Amoreaux West     1
# 183                                           Rosedale     1
# 184                    Stn A PO Boxes 25 The Esplanade     1
# 185                                          Alderwood     0
# 186                                        Long Branch     1
# 187                                          Northwest     1
# 188                                        Upper Rouge     1
# 189                                        Cabbagetown     0
# 190                                     St. James Town     1
# 191                               First Canadian Place     0
# 192                                   Underground city     1
# 193                                       The Kingsway     0
# 194                                    Montgomery Road     0
# 195                                     Old Mill North     1
# 196                               Church and Wellesley     1
# 197   Business Reply Mail Processing Centre 969 Eas...     1
# 198                                         Humber Bay     0
# 199                                   King's Mill Park     0
# 200                           Kingsway Park South East     0
# 201                                          Mimico NE     0
# 202                                     Old Mill South     0
# 203                                 The Queensway East     0
# 204                              Royal York South East     0
# 205                                           Sunnylea     1
# 206                           Kingsway Park South West     0
# 207                                          Mimico NW     0
# 208                                 The Queensway West     0
# 209                              Royal York South West     0
# 210                                     South of Bloor     1
#
#                                  Combined_Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                            Regent Park, Harbourfront
# 4                                     Lawrence Heights
# 5                     Lawrence Manor, Lawrence Heights
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                       Malvern, Rouge
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                     Parkview Hill, Woodbine Gardens
# 13                                             Ryerson
# 14                            Garden District, Ryerson
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                               Islington, Cloverdale
# 18                 Martin Grove, Islington, Cloverdale
# 19    Princess Gardens, Martin Grove, Islington, Cl...
# 20    West Deane Park, Princess Gardens, Martin Gro...
# 21                                      Highland Creek
# 22                          Rouge Hill, Highland Creek
# 23              Port Union, Rouge Hill, Highland Creek
# 24                                     Flemingdon Park
# 25                    Don Mills South, Flemingdon Park
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181   Thistletown, South Steeles, Silverstone, Moun...
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                             Long Branch, Alderwood
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                        St. James Town, Cabbagetown
# 191                               First Canadian Place
# 192             Underground city, First Canadian Place
# 193                                       The Kingsway
# 194                      Montgomery Road, The Kingsway
# 195      Old Mill North, Montgomery Road, The Kingsway
# 196                               Church and Wellesley
# 197   Business Reply Mail Processing Centre 969 Eas...
# 198                                         Humber Bay
# 199                       King's Mill Park, Humber Bay
# 200   Kingsway Park South East, King's Mill Park, H...
# 201   Mimico NE, Kingsway Park South East, King's M...
# 202   Old Mill South, Mimico NE, Kingsway Park Sout...
# 203   The Queensway East, Old Mill South, Mimico NE...
# 204   Royal York South East, The Queensway East, Ol...
# 205   Sunnylea, Royal York South East, The Queenswa...
# 206                           Kingsway Park South West
# 207                Mimico NW, Kingsway Park South West
# 208   The Queensway West, Mimico NW, Kingsway Park ...
# 209   Royal York South West, The Queensway West, Mi...
# 210   South of Bloor, Royal York South West, The Qu...
#
# [211 rows x 5 columns]

# %%
# now only keep flag=1 and drop "Neighborhood"&"flag" and then rename "Combined_Neighborhood"="Neighborhood"
#call the cleansed Toronto data as "df_Toronto"
df3=df2[df2['flag']==1]
df4=df3.drop(columns=['flag','Neighborhood'])
df_Toronto=df4.rename(columns={'Combined_Neighborhood':'Neighborhood'})
df_Toronto
# Out:
#     PostalCode            Borough  \
# 0          M3A         North York
# 1          M4A         North York
# 3          M5A   Downtown Toronto
# 5          M6A         North York
# 6          M7A       Queen's Park
# 7          M9A          Etobicoke
# 9          M1B        Scarborough
# 10         M3B         North York
# 12         M4B          East York
# 14         M5B   Downtown Toronto
# 15         M6B         North York
# 20         M9B          Etobicoke
# 23         M1C        Scarborough
# 25         M3C         North York
# 26         M4C          East York
# 27         M5C   Downtown Toronto
# 28         M6C               York
# 32         M9C          Etobicoke
# 35         M1E        Scarborough
# 36         M4E       East Toronto
# 37         M5E   Downtown Toronto
# 38         M6E               York
# 39         M1G        Scarborough
# 40         M4G          East York
# 41         M5G   Downtown Toronto
# 42         M6G   Downtown Toronto
# 43         M1H        Scarborough
# 44         M2H         North York
# 47         M3H         North York
# 48         M4H          East York
# ..         ...                ...
# 130        M4R    Central Toronto
# 133        M5R    Central Toronto
# 135        M6R       West Toronto
# 136        M7R        Mississauga
# 140        M9R          Etobicoke
# 141        M1S        Scarborough
# 142        M4S    Central Toronto
# 144        M5S   Downtown Toronto
# 146        M6S       West Toronto
# 149        M1T        Scarborough
# 151        M4T    Central Toronto
# 154        M5T   Downtown Toronto
# 158        M1V        Scarborough
# 163        M4V    Central Toronto
# 170        M5V   Downtown Toronto
# 173        M8V          Etobicoke
# 181        M9V          Etobicoke
# 182        M1W        Scarborough
# 183        M4W   Downtown Toronto
# 184        M5W   Downtown Toronto
# 186        M8W          Etobicoke
# 187        M9W          Etobicoke
# 188        M1X        Scarborough
# 190        M4X   Downtown Toronto
# 192        M5X   Downtown Toronto
# 195        M8X          Etobicoke
# 196        M4Y   Downtown Toronto
# 197        M7Y       East Toronto
# 205        M8Y          Etobicoke
# 210        M8Z          Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 3                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 9                                       Malvern, Rouge
# 10                                     Don Mills North
# 12                     Parkview Hill, Woodbine Gardens
# 14                            Garden District, Ryerson
# 15                                           Glencairn
# 20    West Deane Park, Princess Gardens, Martin Gro...
# 23              Port Union, Rouge Hill, Highland Creek
# 25                    Don Mills South, Flemingdon Park
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 32    Old Burnhamthorpe, Markland Wood, Eringate, B...
# 35                   West Hill, Morningside, Guildwood
# 36                                         The Beaches
# 37                                         Berczy Park
# 38                                 Caledonia-Fairbanks
# 39                                              Woburn
# 40                                             Leaside
# 41                                  Central Bay Street
# 42                                            Christie
# 43                                           Cedarbrae
# 44                                   Hillcrest Village
# 47     Wilson Heights, Downsview North, Bathurst Manor
# 48                                    Thorncliffe Park
# ..                                                 ...
# 130                                 North Toronto West
# 133                Yorkville, North Midtown, The Annex
# 135                             Roncesvalles, Parkdale
# 136              Canada Post Gateway Processing Centre
# 140   St. Phillips, Richview Gardens, Martin Grove ...
# 141                                          Agincourt
# 142                                         Davisville
# 144                     University of Toronto, Harbord
# 146                                 Swansea, Runnymede
# 149            Tam O'Shanter, Sullivan, Clarks Corners
# 151                        Summerhill East, Moore Park
# 154          Kensington Market, Grange Park, Chinatown
# 158   Steeles East, Milliken, L'Amoreaux East, Agin...
# 163   Summerhill West, South Hill, Rathnelly, Fores...
# 170   South Niagara, Railway Lands, King and Spadin...
# 173       New Toronto, Mimico South, Humber Bay Shores
# 181   Thistletown, South Steeles, Silverstone, Moun...
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 186                             Long Branch, Alderwood
# 187                                          Northwest
# 188                                        Upper Rouge
# 190                        St. James Town, Cabbagetown
# 192             Underground city, First Canadian Place
# 195      Old Mill North, Montgomery Road, The Kingsway
# 196                               Church and Wellesley
# 197   Business Reply Mail Processing Centre 969 Eas...
# 205   Sunnylea, Royal York South East, The Queenswa...
# 210   South of Bloor, Royal York South West, The Qu...
#
# [103 rows x 3 columns]

# %%
df_Toronto.shape
# Out:
# (103, 3)
