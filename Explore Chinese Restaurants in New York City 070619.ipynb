# %% [markdown]
# <h1 align=center><font size = 5>Explore Chinese Restaurants in New York City</font></h1>

# %% [markdown]
# ## Introduction
#
# The City of New York, usually called either **New York City (NYC)** or simply **New York (NY)**, is the most populous city in the United States.
# New York City consists of five boroughs, each of which is a separate county of the State of New York. The five boroughs – Brooklyn, Queens, Manhattan, The Bronx, and Staten Island – were consolidated into a single city in 1898. The city and its metropolitan area constitute the premier gateway for legal immigration to the United States. As many as 800 languages are spoken in New York, making it the most linguistically diverse city in the world. New York City is home to more than 3.2 million residents born outside the United States, the largest foreign-born population of any city in the world.
#
# New York City has the largest Chinese population of any city outside of Asia and within the U.S. with an estimated population of 573,388 in 2014  and continues to be a primary destination for new Chinese immigrants. New York City is subdivided into official municipal boroughs, which themselves are home to significant Chinese populations, with Brooklyn and Queens, adjacently located on Long Island, leading the fastest growth. After the City of New York itself, the boroughs of Queens and Brooklyn encompass the largest Chinese populations, respectively, of all municipalities in the United States.
#
# So in this project , I will list and visualize all major parts of New York City that has great Chinese restaurants. People who want to run Chinese restaurant business should benefit from it.

# %% [markdown]
# ## Data
#
# The following data will be used in the analysis:
#
# - New York City data that contains list Boroughs, Neighborhoods along with their latitude and longitude.
#      - Data source: https://cocl.us/new_york_dataset
#      - Description: This dataset contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
#
# - Chinese restaurants in each neighborhood of NYC.
#      - Data source: Foursquare API
#      - Description: Start utilizing the Foursquare API to explore the neighborhoods and get Chinese restaurants in each neighborhood.
#
#
# - GeoSpace data
#      - Data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm
#      - Description: By using this geo space data we will get the New york Borough boundaries that will help us visualize choropleth map.

# %% [markdown]
# ## Methodology
#
# - Download and Explore Dataset https://cocl.us/new_york_dataset
# - Using FourSquare API we will find all venues for each neighborhood.
# - Filter out all venues that are Chinese Resturants.
# - Find rating , tips and like count for each Chinese Resturants using FourSquare API.
# - Using rating for each resturant , we will sort that data.
# - Visualize the Ranking of neighborhoods using folium library(python)

# %% [markdown]
# ## Coding

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset https://cocl.us/new_york_dataset

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# Next, let's load the data.

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
#Notice how all the relevant data is in the features key, which is basically a list of the neighborhoods. So, let's define a new variable that includes this data.
neighborhoods_data = newyork_data['features']

neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a pandas dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of New York City.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# #### Create a map of New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'VRX4PSRGXZGY5PK2X230MH1XVRS1MIATJE35D1XYKZT1AUFN' # your Foursquare ID
CLIENT_SECRET = 'LPE1AVUTUPR345XFH55YTF12VJBEYFSBIUCZPTI2BQ5YVXDU' # your Foursquare Secret
VERSION = '20180705' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VRX4PSRGXZGY5PK2X230MH1XVRS1MIATJE35D1XYKZT1AUFN
# CLIENT_SECRET:LPE1AVUTUPR345XFH55YTF12VJBEYFSBIUCZPTI2BQ5YVXDU

# %% [markdown]
# We define a function to intract with FourSquare API and get top 50 venues within a radius of 100 metres for a given latitude and longitude. Below function will return us the venue id , venue name and category.

# %%
LIMIT = 50 # limit of number of venues returned by Foursquare API
radius = 100 # define radius

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['id'], 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue ID',          
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
NYC_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  )


print(NYC_venues.shape)
NYC_venues.head()
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Marble Hill
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Bay Ridge
# Bensonhurst
# Sunset Park
# Greenpoint
# Gravesend
# Brighton Beach
# Sheepshead Bay
# Manhattan Terrace
# Flatbush
# Crown Heights
# East Flatbush
# Kensington
# Windsor Terrace
# Prospect Heights
# Brownsville
# Williamsburg
# Bushwick
# Bedford Stuyvesant
# Brooklyn Heights
# Cobble Hill
# Carroll Gardens
# Red Hook
# Gowanus
# Fort Greene
# Park Slope
# Cypress Hills
# East New York
# Starrett City
# Canarsie
# Flatlands
# Mill Island
# Manhattan Beach
# Coney Island
# Bath Beach
# Borough Park
# Dyker Heights
# Gerritsen Beach
# Marine Park
# Clinton Hill
# Sea Gate
# Downtown
# Boerum Hill
# Prospect Lefferts Gardens
# Ocean Hill
# City Line
# Bergen Beach
# Midwood
# Prospect Park South
# Georgetown
# East Williamsburg
# North Side
# South Side
# Ocean Parkway
# Fort Hamilton
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Astoria
# Woodside
# Jackson Heights
# Elmhurst
# Howard Beach
# Corona
# Forest Hills
# Kew Gardens
# Richmond Hill
# Flushing
# Long Island City
# Sunnyside
# East Elmhurst
# Maspeth
# Ridgewood
# Glendale
# Rego Park
# Woodhaven
# Ozone Park
# South Ozone Park
# College Point
# Whitestone
# Bayside
# Auburndale
# Little Neck
# Douglaston
# Glen Oaks
# Bellerose
# Kew Gardens Hills
# Fresh Meadows
# Briarwood
# Jamaica Center
# Oakland Gardens
# Queens Village
# Hollis
# South Jamaica
# St. Albans
# Rochdale
# Springfield Gardens
# Cambria Heights
# Rosedale
# Far Rockaway
# Broad Channel
# Breezy Point
# Steinway
# Beechhurst
# Bay Terrace
# Edgemere
# Arverne
# Rockaway Beach
# Neponsit
# Murray Hill
# Floral Park
# Holliswood
# Jamaica Estates
# Queensboro Hill
# Hillcrest
# Ravenswood
# Lindenwood
# Laurelton
# Lefrak City
# Belle Harbor
# Rockaway Park
# Somerville
# Brookville
# Bellaire
# North Corona
# Forest Hills Gardens
# St. George
# New Brighton
# Stapleton
# Rosebank
# West Brighton
# Grymes Hill
# Todt Hill
# South Beach
# Port Richmond
# Mariner's Harbor
# Port Ivory
# Castleton Corners
# New Springville
# Travis
# New Dorp
# Oakwood
# Great Kills
# Eltingville
# Annadale
# Woodrow
# Tottenville
# Tompkinsville
# Silver Lake
# Sunnyside
# Ditmas Park
# Wingate
# Rugby
# Park Hill
# Westerleigh
# Graniteville
# Arlington
# Arrochar
# Grasmere
# Old Town
# Dongan Hills
# Midland Beach
# Grant City
# New Dorp Beach
# Bay Terrace
# Huguenot
# Pleasant Plains
# Butler Manor
# Charleston
# Rossville
# Arden Heights
# Greenridge
# Heartland Village
# Chelsea
# Bloomfield
# Bulls Head
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Richmond Town
# Shore Acres
# Clifton
# Concord
# Emerson Hill
# Randall Manor
# Howland Hook
# Elm Park
# Remsen Village
# New Lots
# Paerdegat Basin
# Mill Basin
# Jamaica Hills
# Utopia
# Pomonok
# Astoria Heights
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Sutton Place
# Hunters Point
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Sunnyside Gardens
# Blissville
# Fulton Ferry
# Vinegar Hill
# Weeksville
# Broadway Junction
# Dumbo
# Manor Heights
# Willowbrook
# Sandy Ground
# Egbertville
# Roxbury
# Homecrest
# Middle Village
# Prince's Bay
# Lighthouse Hill
# Richmond Valley
# Malba
# Highland Park
# Madison
# Bronxdale
# Allerton
# Kingsbridge Heights
# Erasmus
# Hudson Yards
# Hammels
# Bayswater
# Queensbridge
# Fox Hills
# (7930, 8)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 4    Wakefield              40.894705              -73.847201
#
#                    Venue ID                                    Venue  \
# 0  4c537892fd2ea593cb077a28                         Lollipops Gelato
# 1  4d6af9426107f04dedeb297a                                 Rite Aid
# 2  4c783cef3badb1f7e4244b54                         Carvel Ice Cream
# 3  508af256e4b0578944c87392  Cooler Runnings Jamaican Restaurant Inc
# 4  4c25c212f1272d7f836385c5                                  Dunkin'
#
#    Venue Latitude  Venue Longitude        Venue Category
# 0       40.894123       -73.845892          Dessert Shop
# 1       40.896649       -73.844846              Pharmacy
# 2       40.890487       -73.848568        Ice Cream Shop
# 3       40.898276       -73.850381  Caribbean Restaurant
# 4       40.890459       -73.849089            Donut Shop

# %% [markdown]
# Let us filter on Chinese Restaurants.

# %%
NYC_Chinese_Rest=NYC_venues.loc[NYC_venues['Venue Category']=='Chinese Restaurant'].reset_index(drop=True)
NYC_Chinese_Rest.head()
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Co-op City              40.874294              -73.829939
# 1     Eastchester              40.887556              -73.827806
# 2         Norwood              40.877224              -73.879391
# 3  Pelham Parkway              40.857413              -73.854756
# 4    Bedford Park              40.870185              -73.885512
#
#                    Venue ID                           Venue  Venue Latitude  \
# 0  4c9d5f2654c8a1cd2e71834b    Guang Hui Chinese Restaurant       40.876603
# 1  4dabc3dc93a04642f09ccabd    Xing Lung Chinese Restaurant       40.888785
# 2  4e41d2c4b61ca5ba3b1f9c6b              Ming Liang Kitchen       40.879996
# 3  4b9d6b45f964a52078ab36e3      Mr. Q's Chinese Restaurant       40.855790
# 4  4e2e08021838f1c552b6b8eb  Choi Yuan - Chinese Restaurant       40.873078
#
#    Venue Longitude      Venue Category
# 0       -73.829710  Chinese Restaurant
# 1       -73.831226  Chinese Restaurant
# 2       -73.876324  Chinese Restaurant
# 3       -73.855455  Chinese Restaurant
# 4       -73.889086  Chinese Restaurant

# %% [markdown]
# So we got data for all Chinese resturants. Now lets save this data to a csv sheet. In case we by mistake modify it. As the number of calls to get details for venue are premium call and have limit of 500 per day, we will refer to saved data sheet csv if required.

# %%
NYC_Chinese_Rest.to_csv('NYC_Chinese_Rest.csv',index=False)

# %%
#left join neighborhoods to get 'Borough' field

NYC_Chinese_Rest_Data=pd.merge(NYC_Chinese_Rest, neighborhoods[['Borough', 'Neighborhood']],
                         on='Neighborhood',
                         how='left')

NYC_Chinese_Rest_Data.head()
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Co-op City              40.874294              -73.829939
# 1     Eastchester              40.887556              -73.827806
# 2         Norwood              40.877224              -73.879391
# 3  Pelham Parkway              40.857413              -73.854756
# 4    Bedford Park              40.870185              -73.885512
#
#                    Venue ID                           Venue  Venue Latitude  \
# 0  4c9d5f2654c8a1cd2e71834b    Guang Hui Chinese Restaurant       40.876603
# 1  4dabc3dc93a04642f09ccabd    Xing Lung Chinese Restaurant       40.888785
# 2  4e41d2c4b61ca5ba3b1f9c6b              Ming Liang Kitchen       40.879996
# 3  4b9d6b45f964a52078ab36e3      Mr. Q's Chinese Restaurant       40.855790
# 4  4e2e08021838f1c552b6b8eb  Choi Yuan - Chinese Restaurant       40.873078
#
#    Venue Longitude      Venue Category Borough
# 0       -73.829710  Chinese Restaurant   Bronx
# 1       -73.831226  Chinese Restaurant   Bronx
# 2       -73.876324  Chinese Restaurant   Bronx
# 3       -73.855455  Chinese Restaurant   Bronx
# 4       -73.889086  Chinese Restaurant   Bronx

# %%
NYC_Chinese_Rest_Data.to_csv('NYC_Chinese_Rest_Data.csv',index=False)

# %%
NYC_Chinese_Rest_Data=pd.read_csv('NYC_Chinese_Rest_Data.csv')

# %%
NYC_Chinese_Rest_Data.shape
# Out:
# (190, 9)

# %% [markdown]
# There are 190 Chinese Restaurants across New York City if we set LIMIT = 50 (limit of number of venues returned by Foursquare API) and radius = 100

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Chinese Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Chinese Resturants', fontsize=15)
#giving a bar plot
NYC_Chinese_Rest_Data.groupby('Borough')['Venue'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# From the plot, we can see that Queens has the largest number of Chinese restaurants.

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Chinese Restaurants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Chinese Restaurants', fontsize=15)
#giving a bar plot
NYC_Chinese_Rest_Data.groupby('Neighborhood')['Venue'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# As the number of calls to get price for venue have limit of 50 per day, I have to break data by each Borough and make sure each data set contains less than 50 records.

# %%
NYC_Chinese_Rest_Data2=NYC_Chinese_Rest_Data[['Borough','Neighborhood','Venue','Venue ID']].rename(columns={"Venue ID":"ID"})
NYC_Chinese_Rest_Data2.head()

# Now break into different Borough: Manhattan
NYC_Chinese_Rest_Data_Manhattan=NYC_Chinese_Rest_Data2[NYC_Chinese_Rest_Data2['Borough']=='Manhattan'].reset_index(drop=True)

# Now break into different Borough: Queens
NYC_Chinese_Rest_Data_Queens=NYC_Chinese_Rest_Data2[NYC_Chinese_Rest_Data2['Borough']=='Queens'].reset_index(drop=True)

NYC_Chinese_Rest_Data_Queens_1=NYC_Chinese_Rest_Data_Queens.head(50).reset_index(drop=True)

NYC_Chinese_Rest_Data_Queens_2=NYC_Chinese_Rest_Data_Queens.tail(13).reset_index(drop=True)

# Now break into different Borough: Brooklyn
NYC_Chinese_Rest_Data_Brooklyn=NYC_Chinese_Rest_Data2[NYC_Chinese_Rest_Data2['Borough']=='Brooklyn'].reset_index(drop=True)

print(NYC_Chinese_Rest_Data_Manhattan.shape)
print(NYC_Chinese_Rest_Data_Queens.shape)
print(NYC_Chinese_Rest_Data_Queens_1.shape)
print(NYC_Chinese_Rest_Data_Queens_2.shape)
print(NYC_Chinese_Rest_Data_Brooklyn.shape)
# Out:
# (26, 4)
# (63, 4)
# (50, 4)
# (13, 4)
# (45, 4)

# %%
NYC_Chinese_Rest_Data_Manhattan
# Out:
#       Borough        Neighborhood                              Venue  \
# 0   Manhattan           Chinatown                      Spicy Village
# 1   Manhattan           Chinatown                 Xi'an Famous Foods
# 2   Manhattan           Chinatown  Wah Fung Number 1 Fast Food 華豐快飯店
# 3   Manhattan           Chinatown              Great N.Y. Noodletown
# 4   Manhattan           Chinatown                 Joe's Shanghai 鹿嗚春
# 5   Manhattan  Washington Heights                        Yang Garden
# 6   Manhattan              Inwood                      Lotus Express
# 7   Manhattan              Inwood                           "U" Like
# 8   Manhattan    Hamilton Heights                         King's Wok
# 9   Manhattan      Manhattanville                        China Place
# 10  Manhattan      Central Harlem              Crispy Bamboo Village
# 11  Manhattan      Central Harlem              88 Chinese Restaurant
# 12  Manhattan          Lenox Hill                           Shanghai
# 13  Manhattan     Upper West Side                        Han Dynasty
# 14  Manhattan             Midtown                 Xi'an Famous Foods
# 15  Manhattan         Murray Hill                          Dun Huang
# 16  Manhattan         Murray Hill                         Café China
# 17  Manhattan             Chelsea                           Buddakan
# 18  Manhattan   Greenwich Village                         Chow House
# 19  Manhattan   Greenwich Village  Junzi Kitchen (Greenwich Village)
# 20  Manhattan        East Village                   Chinese Graffiti
# 21  Manhattan     Lower East Side              Kings County Imperial
# 22  Manhattan             Tribeca                         China Blue
# 23  Manhattan        West Village                              Decoy
# 24  Manhattan        West Village                            RedFarm
# 25  Manhattan    Manhattan Valley                 Xi'an Famous Foods
#
#                           ID
# 0   4db3374590a0843f295fb69b
# 1   5894c9a15e56b417cf79e553
# 2   4a96bf8ff964a520ce2620e3
# 3   3fd66200f964a520b1ea1ee3
# 4   3fd66200f964a52067e61ee3
# 5   4b292f38f964a520939a24e3
# 6   4b9aeeedf964a52086e435e3
# 7   4bd5f4d229eb9c74c64594e1
# 8   4cd76fd7dfb4a1cd7195645c
# 9   4b21974df964a520833e24e3
# 10  4bf348fce5eba593c8711e90
# 11  4bd1f6909854d13a38a2fa4d
# 12  4ea5be4af5b9efc002cccdea
# 13  5529bfd8498ec6ce692d8015
# 14  517021ffe4b0ad9829ae7815
# 15  5bd497a9f427de003989e9d8
# 16  4e3484038877beb5e9a22a0b
# 17  44e9b421f964a520a5371fe3
# 18  5a20df1742d8c2528e74211f
# 19  5b36566f666116002c6b265e
# 20  5c831f04029a550039fcca38
# 21  5b380f649deb7d00399fdf9d
# 22  5237264111d27e8e90c10357
# 23  526eeb54498e9674b5d9034a
# 24  4e1df590b61c7cb34d9735a8
# 25  529e3657498efb17e9c800b7

# %%
def get_url(Venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            Venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    results = requests.get(url).json()['response']['venue']
    return(results)

# %%
Test = get_url(Venue_id='4c87c9930dcb8cfa68e63d68')
Test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-455daa6a7d1e> in <module>
# ----> 1 Test = get_url(Venue_id='4c87c9930dcb8cfa68e63d68')
#       2 Test
#
# <ipython-input-3-588a51b0f866> in get_url(Venue_id)
#       5             CLIENT_SECRET,
#       6             VERSION)
# ----> 7     results = requests.get(url).json()['response']['venue']
#       8     return(results)
#
# KeyError: 'venue'

# %% [markdown]
# First, let us define a function to get venue details like count , price , tip counts for a given venue id. This will be used for getting price.

# %% [markdown]
# Now we will get the price of each resturant for further analysis.

# %% [markdown]
# 1.Manhattan

# %%
# get likes, price, tips
#Manhattan
def get_venue_details(venue_id):
        
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_price=venue_data['price']['message']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_price,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Venue','Likes','Price','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# prepare neighborhood list that contains Chinese restaurants
column_names=['Borough', 'Neighborhood','ID','Venue','Likes','Price','Tips']
NYC_Chinese_Rest_Manhattan_price=pd.DataFrame(columns=column_names)
count=1


for row in NYC_Chinese_Rest_Data_Manhattan.values.tolist():
    Borough,Neighborhood,Venue,ID=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,price,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,price,tips=[0]*5
    print('(',count,'/',len(NYC_Chinese_Rest_Data_Manhattan),')','processed')
    NYC_Chinese_Rest_Manhattan_price = NYC_Chinese_Rest_Manhattan_price.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Venue' : name,
                                                'Likes' : likes,
                                                'Price' : price,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID          Venue  Likes  Price  Tips
# 0  4db3374590a0843f295fb69b  Spicy Village    489  Cheap   181
# ( 1 / 26 ) processed
#                          ID               Venue  Likes  Price  Tips
# 0  5894c9a15e56b417cf79e553  Xi'an Famous Foods     92  Cheap    26
# ( 2 / 26 ) processed
#                          ID                              Venue  Likes  Price  \
# 0  4a96bf8ff964a520ce2620e3  Wah Fung Number 1 Fast Food 華豐快飯店    180  Cheap
#
#    Tips
# 0    91
# ( 3 / 26 ) processed
#                          ID                  Venue  Likes  Price  Tips
# 0  3fd66200f964a520b1ea1ee3  Great N.Y. Noodletown    529  Cheap   285
# ( 4 / 26 ) processed
#                          ID               Venue  Likes     Price  Tips
# 0  3fd66200f964a52067e61ee3  Joe's Shanghai 鹿嗚春   1284  Moderate   568
# ( 5 / 26 ) processed
#                          ID        Venue  Likes     Price  Tips
# 0  4b292f38f964a520939a24e3  Yang Garden      6  Moderate     2
# ( 6 / 26 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4b9aeeedf964a52086e435e3  Lotus Express      7  Cheap     4
# ( 7 / 26 ) processed
#                          ID     Venue  Likes  Price  Tips
# 0  4bd5f4d229eb9c74c64594e1  "U" Like     11  Cheap     7
# ( 8 / 26 ) processed
#                          ID       Venue  Likes  Price  Tips
# 0  4cd76fd7dfb4a1cd7195645c  King's Wok      4  Cheap     4
# ( 9 / 26 ) processed
#                          ID        Venue  Likes      Price  Tips
# 0  4b21974df964a520833e24e3  China Place      4  Expensive     6
# ( 10 / 26 ) processed
#                          ID                  Venue  Likes  Price  Tips
# 0  4bf348fce5eba593c8711e90  Crispy Bamboo Village      9  Cheap     2
# ( 11 / 26 ) processed
#                          ID                  Venue  Likes  Price  Tips
# 0  4bd1f6909854d13a38a2fa4d  88 Chinese Restaurant      8  Cheap     4
# ( 12 / 26 ) processed
#                          ID     Venue  Likes  Price  Tips
# 0  4ea5be4af5b9efc002cccdea  Shanghai     10  Cheap     8
# ( 13 / 26 ) processed
#                          ID        Venue  Likes     Price  Tips
# 0  5529bfd8498ec6ce692d8015  Han Dynasty    306  Moderate    65
# ( 14 / 26 ) processed
#                          ID               Venue  Likes  Price  Tips
# 0  517021ffe4b0ad9829ae7815  Xi'an Famous Foods    922  Cheap   252
# ( 15 / 26 ) processed
#                          ID      Venue  Likes  Price  Tips
# 0  5bd497a9f427de003989e9d8  Dun Huang     15  Cheap     0
# ( 16 / 26 ) processed
#                          ID       Venue  Likes     Price  Tips
# 0  4e3484038877beb5e9a22a0b  Café China   1010  Moderate   274
# ( 17 / 26 ) processed
#                          ID     Venue  Likes      Price  Tips
# 0  44e9b421f964a520a5371fe3  Buddakan   1451  Expensive   508
# ( 18 / 26 ) processed
#                          ID       Venue  Likes     Price  Tips
# 0  5a20df1742d8c2528e74211f  Chow House     56  Moderate     3
# ( 19 / 26 ) processed
#                          ID                              Venue  Likes  Price  \
# 0  5b36566f666116002c6b265e  Junzi Kitchen (Greenwich Village)     47  Cheap
#
#    Tips
# 0     8
# ( 20 / 26 ) processed
#                          ID             Venue  Likes  Price  Tips
# 0  5c831f04029a550039fcca38  Chinese Graffiti      9  Cheap     1
# ( 21 / 26 ) processed
#                          ID                  Venue  Likes  Price  Tips
# 0  5b380f649deb7d00399fdf9d  Kings County Imperial     47  Cheap     6
# ( 22 / 26 ) processed
#                          ID       Venue  Likes      Price  Tips
# 0  5237264111d27e8e90c10357  China Blue    340  Expensive    82
# ( 23 / 26 ) processed
#                          ID  Venue  Likes      Price  Tips
# 0  526eeb54498e9674b5d9034a  Decoy    320  Expensive   104
# ( 24 / 26 ) processed
#                          ID    Venue  Likes      Price  Tips
# 0  4e1df590b61c7cb34d9735a8  RedFarm    699  Expensive   283
# ( 25 / 26 ) processed
#                          ID               Venue  Likes  Price  Tips
# 0  529e3657498efb17e9c800b7  Xi'an Famous Foods    293  Cheap    77
# ( 26 / 26 ) processed

# %%
NYC_Chinese_Rest_Manhattan_price.to_csv('NYC_Chinese_Rest_Manhattan_price.csv',index=False)

# %%
NYC_Chinese_Rest_Manhattan_price.head()
# Out:
#      Borough Neighborhood                        ID  \
# 0  Manhattan    Chinatown  4db3374590a0843f295fb69b
# 1  Manhattan    Chinatown  5894c9a15e56b417cf79e553
# 2  Manhattan    Chinatown  4a96bf8ff964a520ce2620e3
# 3  Manhattan    Chinatown  3fd66200f964a520b1ea1ee3
# 4  Manhattan    Chinatown  3fd66200f964a52067e61ee3
#
#                                Venue Likes     Price Tips
# 0                      Spicy Village   489     Cheap  181
# 1                 Xi'an Famous Foods    92     Cheap   26
# 2  Wah Fung Number 1 Fast Food 華豐快飯店   179     Cheap   91
# 3              Great N.Y. Noodletown   529     Cheap  285
# 4                 Joe's Shanghai 鹿嗚春  1283  Moderate  568

# %% [markdown]
# 2.Queens

# %% [markdown]
# 2.1 Queens data file 1

# %%
# get likes, price, tips
#Queens
def get_venue_details(venue_id):
        
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_price=venue_data['price']['message']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_price,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Venue','Likes','Price','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
# prepare neighborhood list that contains Chinese restaurants
column_names=['Borough', 'Neighborhood','ID','Venue','Likes','Price','Tips']
NYC_Chinese_Rest_Queens_price=pd.DataFrame(columns=column_names)
count=1


for row in NYC_Chinese_Rest_Data_Queens_1.values.tolist():
    Borough,Neighborhood,Venue,ID=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,price,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,price,tips=[0]*5
    print('(',count,'/',len(NYC_Chinese_Rest_Data_Queens_1),')','processed')
    NYC_Chinese_Rest_Queens_price = NYC_Chinese_Rest_Queens_price.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Venue' : name,
                                                'Likes' : likes,
                                                'Price' : price,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID      Venue  Likes  Price  Tips
# 0  5bd497a9f427de003989e9d8  Dun Huang     15  Cheap     0
# ( 1 / 50 ) processed
#                          ID       Venue  Likes     Price  Tips
# 0  4e3484038877beb5e9a22a0b  Café China   1010  Moderate   274
# ( 2 / 50 ) processed
#                          ID               Venue  Likes  Price  Tips
# 0  4ae1d8b2f964a520e78721e3  Peking BBQ Chicken     47  Cheap    24
# ( 3 / 50 ) processed
#                          ID                       Venue  Likes  Price  Tips
# 0  56296f14498edb1ed77b64a3  Five Loaves and Two Fishes     10  Cheap     1
# ( 4 / 50 ) processed
#                          ID         Venue  Likes  Price  Tips
# 0  4eaf0752d3e30d448393b841  Lao Bei Fang     79  Cheap    49
# ( 5 / 50 ) processed
#                          ID                   Venue  Likes  Price  Tips
# 0  4b944c64f964a520907334e3  Sweet Yummy House 三好小馆     17  Cheap     6
# ( 6 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4ba57b0af964a5205f0b39e3  Empire Buffet     19  Cheap     5
# ( 7 / 50 ) processed
#                          ID            Venue  Likes     Price  Tips
# 0  4bc8bd4f92b376b00f16523a  East Meets West      1  Moderate     2
# ( 8 / 50 ) processed
#                          ID                          Venue  Likes     Price  \
# 0  4b68c90ff964a520da8c2be3  Great Wall Chinese Restaurant      5  Moderate
#
#    Tips
# 0     2
# ( 9 / 50 ) processed
#                          ID            Venue  Likes  Price  Tips
# 0  4c350ac6452620a1502b260f  New China Fresh      4  Cheap     4
# ( 10 / 50 ) processed
#                          ID                    Venue  Likes  Price  Tips
# 0  4c585bb82308be9ab3405b6c  Jade Chinese Restaurant      5  Cheap     3
# ( 11 / 50 ) processed
#                          ID                  Venue  Likes  Price  Tips
# 0  4c09da86ffb8c9b6b0bd6a61  Great Taystee Gardens      4  Cheap     6
# ( 12 / 50 ) processed
#                          ID         Venue  Likes  Price  Tips
# 0  4cf167dc7bf3b60ccb8d5f7f  New Shanghai      3  Cheap     0
# ( 13 / 50 ) processed
#                          ID                         Venue  Likes  Price  Tips
# 0  5747a89b498ee4b7a5106556  DunHuang Lanzhou Beef Noodle     29  Cheap    10
# ( 14 / 50 ) processed
#                          ID         Venue  Likes  Price  Tips
# 0  52235ea211d2fe55782d764c  Dong Yi Feng     15  Cheap     1
# ( 15 / 50 ) processed
#                          ID                           Venue  Likes     Price  \
# 0  4af5fd0af964a520daff21e3  Hunan House Chinese Restaurant     31  Moderate
#
#    Tips
# 0    22
# ( 16 / 50 ) processed
#                          ID                   Venue  Likes     Price  Tips
# 0  4abfef82f964a520179320e3  New Imperial Palace 東湖     62  Moderate    31
# ( 17 / 50 ) processed
#                          ID               Venue  Likes  Price  Tips
# 0  5c9a607d25fb7b002c724043  Xi'an Famous Foods      8  Cheap     2
# ( 18 / 50 ) processed
#                          ID             Venue  Likes  Price  Tips
# 0  4b4a7016f964a520a18726e3  Ten Full Chinese      8  Cheap     6
# ( 19 / 50 ) processed
#                          ID          Venue  Likes     Price  Tips
# 0  4aece833f964a52024cc21e3  Tangra Fusion     26  Moderate    15
# ( 20 / 50 ) processed
#                          ID         Venue  Likes  Price  Tips
# 0  4bbd13baa8cf76b0a95fb1fd  China Garden      4  Cheap     2
# ( 21 / 50 ) processed
#                          ID             Venue  Likes  Price  Tips
# 0  4d586ba98147f04db338a254  Yeun Wah Takeout      0  Cheap     0
# ( 22 / 50 ) processed
#                          ID        Venue  Likes  Price  Tips
# 0  4c0d7f6ec700c9b6de84a2dd  Rego Garden      1  Cheap     1
# ( 23 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4d8805b7d85f370481b0c9db  Little Pepper     72  Cheap    37
# ( 24 / 50 ) processed
#                          ID                        Venue  Likes  Price  Tips
# 0  4da8eb9b1e72c1ab9bcfa9da  Kai Ying Chinese Restaurant      1  Cheap     1
# ( 25 / 50 ) processed
#                          ID                   Venue  Likes  Price  Tips
# 0  5a4919463b83074376c5f788  P-Shang Dollar Hot Pot      0  Cheap     0
# ( 26 / 50 ) processed
#                          ID                Venue  Likes  Price  Tips
# 0  53794fd211d282a3cce576a2  Little Dumpling 李小籠     99  Cheap    31
# ( 27 / 50 ) processed
#                          ID               Venue  Likes     Price  Tips
# 0  4bc25d5b4cdfc9b627109621  Northern Manor 同乐轩     43  Moderate    17
# ( 28 / 50 ) processed
#                          ID        Venue  Likes  Price  Tips
# 0  571ab7b2498ed52e0d5f4bca  LN1380 舍得食府     25  Cheap     4
# ( 29 / 50 ) processed
#                          ID     Venue  Likes  Price  Tips
# 0  4bd4debc4e32d13a9419c080  King Wok      1  Cheap     2
# ( 30 / 50 ) processed
#                          ID                              Venue  Likes  Price  \
# 0  49f3a080f964a520c36a1fe3  Dragon Express Chinese Restaurant      0  Cheap
#
#    Tips
# 0     4
# ( 31 / 50 ) processed
#                          ID                            Venue  Likes  Price  \
# 0  4ccc9ea3566aa093dbed22fd  kam's garden chinese restaurant      0  Cheap
#
#    Tips
# 0     0
# ( 32 / 50 ) processed
#                          ID                         Venue  Likes  Price  Tips
# 0  4df56327c65bf55ee53269c2  King Rice Chinese Restaurant      0  Cheap     2
# ( 33 / 50 ) processed
#                          ID            Venue  Likes  Price  Tips
# 0  4bd4c0135631c9b6ec11a330  Annie's Kitchen      3  Cheap     1
# ( 34 / 50 ) processed
#                          ID   Venue  Likes  Price  Tips
# 0  4ba022fbf964a520cf5c37e3  Peking      2  Cheap     2
# ( 35 / 50 ) processed
#                          ID                 Venue  Likes  Price  Tips
# 0  4bc76fe08b7c9c74f97436cf  New Hong Kong Garden      3  Cheap     0
# ( 36 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  5aef90f3b9b37b002ceb20d4  Panda Express      0  Cheap     0
# ( 37 / 50 ) processed
#                          ID            Venue  Likes  Price  Tips
# 0  5a2b366193bd636532b50bdb  Little Dumpling      9  Cheap     1
# ( 38 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4b0ae7a3f964a520c92923e3  Empire Garden      6  Cheap     6
# ( 39 / 50 ) processed
#                          ID       Venue  Likes  Price  Tips
# 0  4e4dfb24bd4101d0d79f8cf5  New Ho Wah      0  Cheap     0
# ( 40 / 50 ) processed
#                          ID                     Venue  Likes  Price  Tips
# 0  4e4e3d94bd4101d0d7a5b3ee  Panda Chinese Restaurant      0  Cheap     0
# ( 41 / 50 ) processed
#                          ID            Venue  Likes     Price  Tips
# 0  4ea312218b81a02f89dcdc67  New Ming Garden      2  Moderate     0
# ( 42 / 50 ) processed
#                          ID        Venue  Likes  Price  Tips
# 0  4c3fb39be26920a1afe65be7  Butterflies      1  Cheap     0
# ( 43 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4c23d8b1f7ced13a6ce0216d  Little Rabbit      1  Cheap     1
# ( 44 / 50 ) processed
#                          ID              Venue  Likes  Price  Tips
# 0  4cf2e1107bf3b60c9320687f  Win Chinese Store      2  Cheap     0
# ( 45 / 50 ) processed
#                          ID      Venue  Likes     Price  Tips
# 0  4e4e41e8bd4101d0d7a620e0  Magic Wok     13  Moderate     8
# ( 46 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4eb9c26046906fa3574d411f  Lucky Cornaga      7  Cheap     0
# ( 47 / 50 ) processed
#                          ID                           Venue  Likes  Price  \
# 0  4e4e41e9bd4101d0d7a620eb  Butterflies Chinese Restaurant      0  Cheap
#
#    Tips
# 0     0
# ( 48 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4bf987b15efe2d7fcc646c34  Emperor House      0  Cheap     0
# ( 49 / 50 ) processed
#                          ID          Venue  Likes  Price  Tips
# 0  4d9bb050b8b2224b84908655  New Hong Kong      0  Cheap     0
# ( 50 / 50 ) processed

# %% [markdown]
# 2.2 Queens data file 2

# %%
# prepare neighborhood list that contains Chinese restaurants
column_names=['Borough', 'Neighborhood','ID','Venue','Likes','Price','Tips']
NYC_Chinese_Rest_Queens_price_2=pd.DataFrame(columns=column_names)
count=1


for row in NYC_Chinese_Rest_Data_Queens_2.values.tolist():
    Borough,Neighborhood,Venue,ID=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,price,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,price,tips=[0]*5
    print('(',count,'/',len(NYC_Chinese_Rest_Data_Queens_2),')','processed')
    NYC_Chinese_Rest_Queens_price_2 = NYC_Chinese_Rest_Queens_price_2.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Venue' : name,
                                                'Likes' : likes,
                                                'Price' : price,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID      Venue  Likes  Price  Tips
# 0  4d69549ede28224b0ac241be  Xing Xing      2  Cheap     3
# ( 1 / 13 ) processed
#                          ID                Venue  Likes  Price  Tips
# 0  505f9fcee4b05a5f27309cdc  Shanghai Cuisine 33     43  Cheap    18
# ( 2 / 13 ) processed
#                          ID                               Venue  Likes  \
# 0  4ac90140f964a520f7bd20e3  Main Street Taiwanese Gourmet 北港台菜     61
#
#       Price  Tips
# 0  Moderate    28
# ( 3 / 13 ) processed
#                          ID                     Venue  Likes     Price  Tips
# 0  4f844c6fe4b0059705cb042c  Lake Pavilion Restaurant    115  Moderate    42
# ( 4 / 13 ) processed
#                          ID       Venue  Likes  Price  Tips
# 0  4c56000b3e2220a163eb3ea5  88 Canteen     15  Cheap    10
# ( 5 / 13 ) processed
#                          ID                    Venue  Likes  Price  Tips
# 0  4ba94febf964a520c71d3ae3  Happy Garden Restaurant      1  Cheap     4
# ( 6 / 13 ) processed
#                          ID                   Venue  Likes  Price  Tips
# 0  4ae78dbff964a52056ac21e3  Fatima's Halal Kitchen     41  Cheap    31
# ( 7 / 13 ) processed
#                          ID            Venue  Likes  Price  Tips
# 0  4c02eb2e39d476b0e9652fa7  East Meets West      2  Cheap    11
# ( 8 / 13 ) processed
#                          ID       Venue  Likes  Price  Tips
# 0  4c59c1d3d3aee21ea2066955  China King      3  Cheap     3
# ( 9 / 13 ) processed
#                          ID          Venue  Likes     Price  Tips
# 0  4ce49482e571a09332bc8587  Sagar Chinese     17  Moderate    15
# ( 10 / 13 ) processed
#                          ID              Venue  Likes  Price  Tips
# 0  57b902d4498ea31e223ebd15  Dhanshiri Chinese      3  Cheap     2
# ( 11 / 13 ) processed
#                          ID             Venue  Likes  Price  Tips
# 0  4ce1a341eae02c0f8ec7b726  A Taste of China      0  Cheap     0
# ( 12 / 13 ) processed
#                          ID       Venue  Likes  Price  Tips
# 0  4bb91c86b35776b0e5a1c901  Golden Wok      7  Cheap     4
# ( 13 / 13 ) processed

# %%
NYC_Chinese_Rest_Queens_price.to_csv('NYC_Chinese_Rest_Queens_price_1.csv',index=False)

# %%
NYC_Chinese_Rest_Queens_price_2.to_csv('NYC_Chinese_Rest_Queens_price_2.csv',index=False)

# %%
f1=pd.read_csv('NYC_Chinese_Rest_Queens_price_1.csv')
f2=pd.read_csv('NYC_Chinese_Rest_Queens_price_2.csv')
f3=pd.read_csv('NYC_Chinese_Rest_Manhattan_price.csv')

f=f1.append(f2).append(f3)
print(f1.shape)
print(f2.shape)
print(f3.shape)
print(f.shape)
# Out:
# (50, 7)
# (13, 7)
# (26, 7)
# (89, 7)

# %%
# get likes, price, tips
#Brooklyn
def get_venue_details(venue_id):
        
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_price=venue_data['price']['message']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_price,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Venue','Likes','Price','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# prepare neighborhood list that contains Chinese restaurants
column_names=['Borough', 'Neighborhood','ID','Venue','Likes','Price','Tips']
NYC_Chinese_Rest_Brooklyn_price_2=pd.DataFrame(columns=column_names)
count=1


for row in NYC_Chinese_Rest_Data_Brooklyn.values.tolist():
    Borough,Neighborhood,Venue,ID=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,price,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,price,tips=[0]*5
    print('(',count,'/',len(NYC_Chinese_Rest_Data_Brooklyn),')','processed')
    NYC_Chinese_Rest_Brooklyn_price= NYC_Chinese_Rest_Brooklyn_price.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Venue' : name,
                                                'Likes' : likes,
                                                'Price' : price,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1

# %%
# Out:
#       Borough         Neighborhood                        ID  \
# 0      Queens          Murray Hill  5bd497a9f427de003989e9d8
# 1      Queens          Murray Hill  4e3484038877beb5e9a22a0b
# 2      Queens             Woodside  4ae1d8b2f964a520e78721e3
# 3      Queens             Elmhurst  56296f14498edb1ed77b64a3
# 4      Queens             Elmhurst  4eaf0752d3e30d448393b841
# 5      Queens             Elmhurst  4b944c64f964a520907334e3
# 6      Queens         Howard Beach  4ba57b0af964a5205f0b39e3
# 7      Queens         Howard Beach  4bc8bd4f92b376b00f16523a
# 8      Queens         Forest Hills  4b68c90ff964a520da8c2be3
# 9      Queens          Kew Gardens  4c350ac6452620a1502b260f
# 10     Queens          Kew Gardens  4c585bb82308be9ab3405b6c
# 11     Queens          Kew Gardens  4c09da86ffb8c9b6b0bd6a61
# 12     Queens          Kew Gardens  4cf167dc7bf3b60ccb8d5f7f
# 13     Queens             Flushing  5747a89b498ee4b7a5106556
# 14     Queens             Flushing  52235ea211d2fe55782d764c
# 15     Queens             Flushing  4af5fd0af964a520daff21e3
# 16     Queens             Flushing  4abfef82f964a520179320e3
# 17     Queens     Long Island City  5c9a607d25fb7b002c724043
# 18     Queens            Sunnyside  4b4a7016f964a520a18726e3
# 19     Queens            Sunnyside  4aece833f964a52024cc21e3
# 20     Queens            Sunnyside  4bbd13baa8cf76b0a95fb1fd
# 21     Queens              Maspeth  4d586ba98147f04db338a254
# 22     Queens            Rego Park  4c0d7f6ec700c9b6de84a2dd
# 23     Queens        College Point  4d8805b7d85f370481b0c9db
# 24     Queens        College Point  4da8eb9b1e72c1ab9bcfa9da
# 25     Queens        College Point  5a4919463b83074376c5f788
# 26     Queens          Little Neck  53794fd211d282a3cce576a2
# 27     Queens          Little Neck  4bc25d5b4cdfc9b627109621
# 28     Queens          Little Neck  571ab7b2498ed52e0d5f4bca
# 29     Queens           Douglaston  4bd4debc4e32d13a9419c080
# 30     Queens           Douglaston  49f3a080f964a520c36a1fe3
# 31     Queens            Bellerose  4ccc9ea3566aa093dbed22fd
# 32     Queens            Bellerose  4df56327c65bf55ee53269c2
# 33     Queens    Kew Gardens Hills  4bd4c0135631c9b6ec11a330
# 34     Queens        Fresh Meadows  4ba022fbf964a520cf5c37e3
# 35     Queens        Fresh Meadows  4bc76fe08b7c9c74f97436cf
# 36     Queens       Jamaica Center  5aef90f3b9b37b002ceb20d4
# 37     Queens      Oakland Gardens  5a2b366193bd636532b50bdb
# 38     Queens      Oakland Gardens  4b0ae7a3f964a520c92923e3
# 39     Queens               Hollis  4e4dfb24bd4101d0d79f8cf5
# 40     Queens           St. Albans  4e4e3d94bd4101d0d7a5b3ee
# 41     Queens             Rochdale  4ea312218b81a02f89dcdc67
# 42     Queens  Springfield Gardens  4c3fb39be26920a1afe65be7
# 43     Queens      Cambria Heights  4c23d8b1f7ced13a6ce0216d
# 44     Queens             Rosedale  4cf2e1107bf3b60c9320687f
# 45     Queens         Far Rockaway  4e4e41e8bd4101d0d7a620e0
# 46     Queens         Far Rockaway  4eb9c26046906fa3574d411f
# 47     Queens         Far Rockaway  4e4e41e9bd4101d0d7a620eb
# 48     Queens           Beechhurst  4bf987b15efe2d7fcc646c34
# 49     Queens           Beechhurst  4d9bb050b8b2224b84908655
# 0      Queens       Rockaway Beach  4d69549ede28224b0ac241be
# 1      Queens      Queensboro Hill  505f9fcee4b05a5f27309cdc
# 2      Queens      Queensboro Hill  4ac90140f964a520f7bd20e3
# 3      Queens      Queensboro Hill  4f844c6fe4b0059705cb042c
# 4      Queens      Queensboro Hill  4c56000b3e2220a163eb3ea5
# 5      Queens      Queensboro Hill  4ba94febf964a520c71d3ae3
# 6      Queens           Ravenswood  4ae78dbff964a52056ac21e3
# 7      Queens         Belle Harbor  4c02eb2e39d476b0e9652fa7
# 8      Queens             Bellaire  4c59c1d3d3aee21ea2066955
# 9      Queens        Jamaica Hills  4ce49482e571a09332bc8587
# 10     Queens        Jamaica Hills  57b902d4498ea31e223ebd15
# 11     Queens               Utopia  4ce1a341eae02c0f8ec7b726
# 12     Queens    Sunnyside Gardens  4bb91c86b35776b0e5a1c901
# 0   Manhattan            Chinatown  4db3374590a0843f295fb69b
# 1   Manhattan            Chinatown  5894c9a15e56b417cf79e553
# 2   Manhattan            Chinatown  4a96bf8ff964a520ce2620e3
# 3   Manhattan            Chinatown  3fd66200f964a520b1ea1ee3
# 4   Manhattan            Chinatown  3fd66200f964a52067e61ee3
# 5   Manhattan   Washington Heights  4b292f38f964a520939a24e3
# 6   Manhattan               Inwood  4b9aeeedf964a52086e435e3
# 7   Manhattan               Inwood  4bd5f4d229eb9c74c64594e1
# 8   Manhattan     Hamilton Heights  4cd76fd7dfb4a1cd7195645c
# 9   Manhattan       Manhattanville  4b21974df964a520833e24e3
# 10  Manhattan       Central Harlem  4bf348fce5eba593c8711e90
# 11  Manhattan       Central Harlem  4bd1f6909854d13a38a2fa4d
# 12  Manhattan           Lenox Hill  4ea5be4af5b9efc002cccdea
# 13  Manhattan      Upper West Side  5529bfd8498ec6ce692d8015
# 14  Manhattan              Midtown  517021ffe4b0ad9829ae7815
# 15  Manhattan          Murray Hill  5bd497a9f427de003989e9d8
# 16  Manhattan          Murray Hill  4e3484038877beb5e9a22a0b
# 17  Manhattan              Chelsea  44e9b421f964a520a5371fe3
# 18  Manhattan    Greenwich Village  5a20df1742d8c2528e74211f
# 19  Manhattan    Greenwich Village  5b36566f666116002c6b265e
# 20  Manhattan         East Village  5c831f04029a550039fcca38
# 21  Manhattan      Lower East Side  5b380f649deb7d00399fdf9d
# 22  Manhattan              Tribeca  5237264111d27e8e90c10357
# 23  Manhattan         West Village  526eeb54498e9674b5d9034a
# 24  Manhattan         West Village  4e1df590b61c7cb34d9735a8
# 25  Manhattan     Manhattan Valley  529e3657498efb17e9c800b7
#
#                                  Venue  Likes      Price  Tips
# 0                            Dun Huang     15      Cheap     0
# 1                           Café China   1010   Moderate   274
# 2                   Peking BBQ Chicken     47      Cheap    24
# 3           Five Loaves and Two Fishes     10      Cheap     1
# 4                         Lao Bei Fang     79      Cheap    49
# 5               Sweet Yummy House 三好小馆     17      Cheap     6
# 6                        Empire Buffet     19      Cheap     5
# 7                      East Meets West      1   Moderate     2
# 8        Great Wall Chinese Restaurant      5   Moderate     2
# 9                      New China Fresh      4      Cheap     4
# 10             Jade Chinese Restaurant      5      Cheap     3
# 11               Great Taystee Gardens      4      Cheap     6
# 12                        New Shanghai      3      Cheap     0
# 13        DunHuang Lanzhou Beef Noodle     29      Cheap    10
# 14                        Dong Yi Feng     15      Cheap     1
# 15      Hunan House Chinese Restaurant     31   Moderate    22
# 16              New Imperial Palace 東湖     62   Moderate    31
# 17                  Xi'an Famous Foods      8      Cheap     2
# 18                    Ten Full Chinese      8      Cheap     6
# 19                       Tangra Fusion     26   Moderate    15
# 20                        China Garden      4      Cheap     2
# 21                    Yeun Wah Takeout      0      Cheap     0
# 22                         Rego Garden      1      Cheap     1
# 23                       Little Pepper     72      Cheap    37
# 24         Kai Ying Chinese Restaurant      1      Cheap     1
# 25              P-Shang Dollar Hot Pot      0      Cheap     0
# 26                 Little Dumpling 李小籠     99      Cheap    31
# 27                  Northern Manor 同乐轩     43   Moderate    17
# 28                         LN1380 舍得食府     25      Cheap     4
# 29                            King Wok      1      Cheap     2
# 30   Dragon Express Chinese Restaurant      0      Cheap     4
# 31     kam's garden chinese restaurant      0      Cheap     0
# 32        King Rice Chinese Restaurant      0      Cheap     2
# 33                     Annie's Kitchen      3      Cheap     1
# 34                              Peking      2      Cheap     2
# 35                New Hong Kong Garden      3      Cheap     0
# 36                       Panda Express      0      Cheap     0
# 37                     Little Dumpling      9      Cheap     1
# 38                       Empire Garden      6      Cheap     6
# 39                          New Ho Wah      0      Cheap     0
# 40            Panda Chinese Restaurant      0      Cheap     0
# 41                     New Ming Garden      2   Moderate     0
# 42                         Butterflies      1      Cheap     0
# 43                       Little Rabbit      1      Cheap     1
# 44                   Win Chinese Store      2      Cheap     0
# 45                           Magic Wok     13   Moderate     8
# 46                       Lucky Cornaga      7      Cheap     0
# 47      Butterflies Chinese Restaurant      0      Cheap     0
# 48                       Emperor House      0      Cheap     0
# 49                       New Hong Kong      0      Cheap     0
# 0                            Xing Xing      2      Cheap     3
# 1                  Shanghai Cuisine 33     43      Cheap    18
# 2   Main Street Taiwanese Gourmet 北港台菜     61   Moderate    28
# 3             Lake Pavilion Restaurant    115   Moderate    42
# 4                           88 Canteen     15      Cheap    10
# 5              Happy Garden Restaurant      1      Cheap     4
# 6               Fatima's Halal Kitchen     41      Cheap    31
# 7                      East Meets West      2      Cheap    11
# 8                           China King      3      Cheap     3
# 9                        Sagar Chinese     17   Moderate    15
# 10                   Dhanshiri Chinese      3      Cheap     2
# 11                    A Taste of China      0      Cheap     0
# 12                          Golden Wok      7      Cheap     4
# 0                        Spicy Village    489      Cheap   181
# 1                   Xi'an Famous Foods     92      Cheap    26
# 2    Wah Fung Number 1 Fast Food 華豐快飯店    180      Cheap    91
# 3                Great N.Y. Noodletown    529      Cheap   285
# 4                   Joe's Shanghai 鹿嗚春   1284   Moderate   568
# 5                          Yang Garden      6   Moderate     2
# 6                        Lotus Express      7      Cheap     4
# 7                             "U" Like     11      Cheap     7
# 8                           King's Wok      4      Cheap     4
# 9                          China Place      4  Expensive     6
# 10               Crispy Bamboo Village      9      Cheap     2
# 11               88 Chinese Restaurant      8      Cheap     4
# 12                            Shanghai     10      Cheap     8
# 13                         Han Dynasty    306   Moderate    65
# 14                  Xi'an Famous Foods    922      Cheap   252
# 15                           Dun Huang     15      Cheap     0
# 16                          Café China   1010   Moderate   274
# 17                            Buddakan   1451  Expensive   508
# 18                          Chow House     56   Moderate     3
# 19   Junzi Kitchen (Greenwich Village)     47      Cheap     8
# 20                    Chinese Graffiti      9      Cheap     1
# 21               Kings County Imperial     47      Cheap     6
# 22                          China Blue    340  Expensive    82
# 23                               Decoy    320  Expensive   104
# 24                             RedFarm    699  Expensive   283
# 25                  Xi'an Famous Foods    293      Cheap    77

# %%
# Resturant with maximum Likes
f.iloc[f['Likes'].idxmax()]
# Out:
# Borough                           Queens
# Neighborhood            Long Island City
# ID              5c9a607d25fb7b002c724043
# Venue                 Xi'an Famous Foods
# Likes                                  8
# Price                              Cheap
# Tips                                   2
# Name: 17, dtype: object

# %%
# Resturant with maximum Tips
f.iloc[f['Tips'].idxmax()]
# Out:
# Borough                           Queens
# Neighborhood                    Elmhurst
# ID              4eaf0752d3e30d448393b841
# Venue                       Lao Bei Fang
# Likes                                 79
# Price                              Cheap
# Tips                                  49
# Name: 4, dtype: object

# %% [markdown]
# Now Lets visualize Borough with average likes.

# %%
ny_borough_stats=f.groupby('Borough',as_index=False).mean()[['Borough','Likes']]
ny_borough_stats.columns=['Borough','Average Likes']
ny_borough_stats.sort_values(['Average Likes'],ascending=False)
# Out:
#      Borough  Average Likes
# 0  Manhattan     313.384615
# 1     Queens      31.793651

# %%
# lets visualize it
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average Likes of Chinese Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Likes', fontsize=15)
#giving a bar plot
f.groupby('Borough').mean()['Likes'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# Now Lets visualize Borough with average tips.

# %%
ny_borough_stats=f.groupby('Borough',as_index=False).mean()[['Borough','Tips']]
ny_borough_stats.columns=['Borough','Average Tips']
ny_borough_stats.sort_values(['Average Tips'],ascending=False)
# Out:
#      Borough  Average Tips
# 0  Manhattan    109.653846
# 1     Queens     11.968254

# %%
# lets visualize it
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average Tips of Chinese Resturants for each Borough')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Tips', fontsize=15)
#giving a bar plot
f.groupby('Borough').mean()['Tips'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
f_price=f.groupby(['Borough', 'Price']).size()
f_price.groupby(level=0).apply(lambda x: 100*x/float(x.sum()))
# Out:
# Borough    Price
# Manhattan  Cheap        61.538462
#            Expensive    19.230769
#            Moderate     19.230769
# Queens     Cheap        80.952381
#            Moderate     19.047619
# dtype: float64

# %% [markdown]
# From above, we can see that around 81% Chinese restaurants in Queens with price "Cheap" while only aournd 62% Chinese restaurants in Manhattan with price "Cheap".

# %% [markdown]
# ## Conclusion
# - Queens,Brooklyn are top two boroughs that have most Chinese restaurants.
# - Manhattan have potential Chinese Restaurant Market.
# - Manhattan has the top average numer of "Likes" and the average number of "Tips"
# - The majority group of Chinese restaurants charge low price. But Manhattan has some top grade Chinese restaurants.

# %% [markdown]
# ## Limitations
# - The accuracy of data depends purely on the data provided by Foursqure.
# - Not all the restaurants got rating so rating is not included in the analysis.
